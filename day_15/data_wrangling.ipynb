# %% [markdown]
# # Data Wrangling

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Step-1 Data Gathering

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info
# Out:
# <bound method DataFrame.info of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# # Step-3 clean the data

# %%
df.isnull().sum() / len(df) * 100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# # Step-3.1 Dealing with missing value
# . remove the data

# %%
df.drop(columns="deck", inplace = True)

# %%
df.isnull().sum() / len(df) *100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
# mean fill karna ha
df['age'] = df.age.fillna(value = df['age'].mean)

# %%
df.isnull().sum() / len(df) * 100
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.000000
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.224467
# class          0.000000
# who            0.000000
# adult_male     0.000000
# embark_town    0.224467
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
df['embark_town'] = df.embark_town.fillna(value = df['embark_town'].mode)

# %%
df.isnull().sum() / len(df) * 100
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.000000
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.224467
# class          0.000000
# who            0.000000
# adult_male     0.000000
# embark_town    0.000000
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
df['embarked'] = df.embarked.fillna(value= df['embarked'].median)

# %%
df.isnull().sum() / len(df) * 100
# Out:
# survived       0.0
# pclass         0.0
# sex            0.0
# age            0.0
# sibsp          0.0
# parch          0.0
# fare           0.0
# embarked       0.0
# class          0.0
# who            0.0
# adult_male     0.0
# embark_town    0.0
# alive          0.0
# alone          0.0
# dtype: float64

# %% [markdown]
# # Step-3.2 Correcting errors in the data
# # 3.2.1 Outlier removal

# %%
import seaborn as sns

# %%
sns.boxplot(data=df, x='age', y='sex')
# Out:
# <Axes: xlabel='age', ylabel='sex'>

# %% [markdown]
# # 3.2.2 IQR

# %%
Q1 = df['fare'].quantile(0.25)
Q3 = df['fare'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# np.float64(23.0896)

# %%
#create a equation remove a outliers levels ky sath assignmnt
lower_bound = Q1 - 1.5 * IQR
upper_bound =Q3 + 1.5 * IQR
df = df[(df['fare']> lower_bound) & (df['fare']<upper_bound)]
df
# Out:
#      survived  pclass     sex  \
# 0           0       3    male
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# 5           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
#                                                    age  sibsp  parch     fare  \
# 0                                                 22.0      1      0   7.2500
# 2                                                 26.0      0      0   7.9250
# 3                                                 35.0      1      0  53.1000
# 4                                                 35.0      0      0   8.0500
# 5    <bound method Series.mean of 0      22.0\n1   ...      0      0   8.4583
# ..                                                 ...    ...    ...      ...
# ...

# %%
df.shape
# Out:
# (775, 14)

# %%
sns.histplot(df['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
# pip install scipy

# %% [markdown]
# # Step-3.3 Finding and dropping duplicates

# %%
#finding duplicates
df.duplicated().sum()
# Out:
# np.int64(105)

# %%
#where is duplicate
df_dup = df[df.duplicated()]

# %%
df_dup.head()
# Out:
#     survived  pclass     sex  \
# 47         1       3  female
# 76         0       3    male
# 77         0       3    male
# 87         0       3    male
# 95         0       3    male
#
#                                                   age  sibsp  parch    fare  \
# 47  <bound method Series.mean of 0      22.0\n1   ...      0      0  7.7500
# 76  <bound method Series.mean of 0      22.0\n1   ...      0      0  7.8958
# 77  <bound method Series.mean of 0      22.0\n1   ...      0      0  8.0500
# 87  <bound method Series.mean of 0      22.0\n1   ...      0      0  8.0500
# 95  <bound method Series.mean of 0      22.0\n1   ...      0      0  8.0500
#
#    embarked  class    who  adult_male  embark_town alive  alone
# 47        Q  Third  woman       False   Queenstown   yes   True
# 76        S  Third    man        True  Southampton    no   True
# 77        S  Third    man        True  Southampton    no   True
# 87        S  Third    man        True  Southampton    no   True
# ...

# %%
df_dup.shape
# Out:
# (105, 14)

# %%
#Dropping duplicated 
df.drop_duplicates(inplace=True)
# Out:
# C:\Users\HKT\AppData\Local\Temp\ipykernel_18392\3921076424.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (670, 14)

# %% [markdown]
# # Step-4 Transforming the data
# ## 4.1 normaliza the data (data wrangling)

# %%
# pip install scikit-learn

# %%
# 1-import libraries
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
# 2-data
df
# Out:
#      survived  pclass     sex  \
# 0           0       3    male
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# 5           0       3    male
# ..        ...     ...     ...
# 885         0       3  female
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
#                                                    age  sibsp  parch     fare  \
# 0                                                 22.0      1      0   7.2500
# 2                                                 26.0      0      0   7.9250
# 3                                                 35.0      1      0  53.1000
# 4                                                 35.0      0      0   8.0500
# 5    <bound method Series.mean of 0      22.0\n1   ...      0      0   8.4583
# ..                                                 ...    ...    ...      ...
# ...

# %%
# 3-select columns to normalize
col_to_normalize = ['fare']

# %%
# 4-create the scaler function
scaler = MinMaxScaler()

# %%
# 5- fit and tranform the data on scaler
df[col_to_normalize] = scaler.fit_transform(df[col_to_normalize])
# Out:
# C:\Users\HKT\AppData\Local\Temp\ipykernel_18392\1494597933.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_to_normalize] = scaler.fit_transform(df[col_to_normalize])

# %%
df
# Out:
#      survived  pclass     sex  \
# 0           0       3    male
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# 5           0       3    male
# ..        ...     ...     ...
# 885         0       3  female
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
#                                                    age  sibsp  parch  \
# 0                                                 22.0      1      0
# 2                                                 26.0      0      0
# 3                                                 35.0      1      0
# 4                                                 35.0      0      0
# 5    <bound method Series.mean of 0      22.0\n1   ...      0      0
# ..                                                 ...    ...    ...
# 885                                               39.0      0      5
# ...

# %%
df.describe()
# Out:
#          survived      pclass       sibsp       parch        fare
# count  670.000000  670.000000  670.000000  670.000000  670.000000
# mean     0.364179    2.437313    0.482090    0.388060    0.291663
# std      0.481559    0.756504    0.938533    0.832006    0.213785
# min      0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000    0.000000    0.121474
# 50%      0.000000    3.000000    0.000000    0.000000    0.200000
# 75%      1.000000    3.000000    1.000000    0.000000    0.404407
# max      1.000000    3.000000    5.000000    6.000000    1.000000

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalers = StandardScaler()

# %%
df[col_to_normalize]  = scalers.fit_transform(df[col_to_normalize])
# Out:
# C:\Users\HKT\AppData\Local\Temp\ipykernel_18392\3246160636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_to_normalize]  = scalers.fit_transform(df[col_to_normalize])

# %%
df.describe()
# Out:
#          survived      pclass       sibsp       parch          fare
# count  670.000000  670.000000  670.000000  670.000000  6.700000e+02
# mean     0.364179    2.437313    0.482090    0.388060 -1.060512e-17
# std      0.481559    0.756504    0.938533    0.832006  1.000747e+00
# min      0.000000    1.000000    0.000000    0.000000 -1.365302e+00
# 25%      0.000000    2.000000    0.000000    0.000000 -7.966718e-01
# 50%      0.000000    3.000000    0.000000    0.000000 -4.290834e-01
# 75%      1.000000    3.000000    1.000000    0.000000  5.277649e-01
# max      1.000000    3.000000    5.000000    6.000000  3.315793e+00

# %% [markdown]
# # Step-4.1.3 log transformation

# %%
kashti = sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import numpy as np

# %%
kashti['age'] = kashti['age'].fillna(kashti['age'].median)

# %%
kashti['fare'] = kashti['fare'].fillna(kashti['fare'].median)

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# log tranform
kashti['fare'] = np.log(kashti['fare'])
# Out:
# c:\Users\HKT\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  1.981001        S  Third
# 1         1       1  female  38.0      1      0  4.266662        C  First
# 2         1       3  female  26.0      0      0  2.070022        S  Third
# 3         1       1  female  35.0      1      0  3.972177        S  First
# 4         0       3    male  35.0      0      0  2.085672        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(data = df , x='sex', y='fare')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.histplot(kashti['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %% [markdown]
# # Step-6 Organizing the data

# %%
df['family_size'] = df['sibsp'] + df['parch']
# Out:
# C:\Users\HKT\AppData\Local\Temp\ipykernel_18392\1288543030.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['family_size'] = df['sibsp'] + df['parch']

# %%
sns.histplot(df, x='family_size')
# Out:
# <Axes: xlabel='family_size', ylabel='Count'>

# %%
sns.histplot(df['family_size'])
# Out:
# <Axes: xlabel='family_size', ylabel='Count'>

# %%
sns.swarmplot(df, x='sex', y='fare', hue='family_size')
# Out:
# c:\Users\HKT\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 23.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='sex', ylabel='fare'>
# c:\Users\HKT\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 31.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\HKT\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#rename the data
df = df.rename(columns={'survived':'survival'})

# %%
df.columns
# Out:
# Index(['survival', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'family_size'],
#       dtype='object')

# %%
#grouping the data
table = pd.pivot_table(df, values='fare', index= 'pclass'
                       , columns='survival', aggfunc=np.mean)
table
# Out:
# C:\Users\HKT\AppData\Local\Temp\ipykernel_18392\4027786846.py:2: FutureWarning: The provided callable <function mean at 0x000001CE4904C220> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   table = pd.pivot_table(df, values='fare', index= 'pclass'
# survival         0         1
# pclass
# 1         1.113358  1.548143
# 2        -0.070898  0.245399
# 3        -0.395955 -0.414654

# %%
table = pd.pivot_table(df, values='fare', index= 'sex'
                       , columns='survival', aggfunc=np.mean)
table
# Out:
# C:\Users\HKT\AppData\Local\Temp\ipykernel_18392\3073378935.py:1: FutureWarning: The provided callable <function mean at 0x000001CE4904C220> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   table = pd.pivot_table(df, values='fare', index= 'sex'
# survival         0         1
# sex
# female   -0.088491  0.273677
# male     -0.167219  0.259666

# %% [markdown]
# # Step-7 Saving the data

# %%
df.to_csv('preprocessed_data.csv')

# %%
sns.lineplot(data = df, x='family_size', y='fare')
# Out:
# <Axes: xlabel='family_size', ylabel='fare'>

# %%
# Steps:Data Wrangling:
# 1. Gathering the data
# 2. Assesing the data 
# 3. Clean the data
#    1. Dealing with missing values
#    2. Correcting errors in the data
#       1. outliers removal
#          1.Visualization
#          2. IQR method
#          3. Z-score(assignment)
#    3 Droping duplicates
# 4.Transforming the data
#     1.nomalize the data(data wrangling)
#        1.min-max normalization
#        2.standard scaler
#        3.log tranformation
#        4.winsorization
#        5.Z-score normalization
#        6.Decimal scaling
# 5.Feature Engineering(ya abi karna ha)
# 6.Organizing data
#    1.columns creation
#    2.Renaming jis kis sense banti ha
# 7.Saving the data to be used


# You should remember eyerthing.
# it depend on data.how to handling data.
