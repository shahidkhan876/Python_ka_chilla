# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("orderd.csv")
df.head()
# Out:
#   productCode  quantityOrdered  priceEach
# 0    S18_1749               30     136.00
# 1    S18_2248               50      55.09
# 2    S18_4409               22      75.46
# 3    S24_3969               49      35.29
# 4    S18_2325               25     108.06

# %%
sns.histplot(df["priceEach"])
# Out:
# <Axes: xlabel='priceEach', ylabel='Count'>

# %%
sns.barplot(df["priceEach"])
# Out:
# <Axes: ylabel='priceEach'>

# %%
plt.boxplot(df["priceEach"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1db46257b10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1db46257d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1db462579d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1db461e4050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1db461e4190>],
#  'means': []}

# %%
sns.boxplot(df["priceEach"])
# Out:
# <Axes: ylabel='priceEach'>
