# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv("employee.csv")
# Out:
#     employeeNumber   lastName firstName                            email
# 0             1611     Fixter      Andy     afixter@classicmodelcars.com
# 1             1143        Bow   Anthony        abow@classicmodelcars.com
# 2             1504      Jones     Barry      bjones@classicmodelcars.com
# 3             1002     Murphy     Diane     dmurphy@classicmodelcars.com
# 4             1286      Tseng  Foon Yue      ftseng@classicmodelcars.com
# 5             1323     Vanauf    George     gvanauf@classicmodelcars.com
# 6             1102     Bondur    Gerard     gbondur@classicmodelcars.com
# 7             1370  Hernandez    Gerard   ghernande@classicmodelcars.com
# 8             1076   Firrelli      Jeff   jfirrelli@classicmodelcars.com
# 9             1188   Firrelli     Julie   jfirrelli@classicmodelcars.com
# 10            1501       Bott     Larry       lbott@classicmodelcars.com
# 11            1165   Jennings    Leslie   ljennings@classicmodelcars.com
# ...

# %%
df = pd.read_csv("employee.csv")
df.head()
# Out:
#    employeeNumber lastName firstName                         email
# 0            1611   Fixter      Andy  afixter@classicmodelcars.com
# 1            1143      Bow   Anthony     abow@classicmodelcars.com
# 2            1504    Jones     Barry   bjones@classicmodelcars.com
# 3            1002   Murphy     Diane  dmurphy@classicmodelcars.com
# 4            1286    Tseng  Foon Yue   ftseng@classicmodelcars.com

# %%
sns.histplot(df["email"])
# Out:
# <Axes: xlabel='email', ylabel='Count'>

# %%
sns.histplot(df['firstName'])
# Out:
# <Axes: xlabel='firstName', ylabel='Count'>
