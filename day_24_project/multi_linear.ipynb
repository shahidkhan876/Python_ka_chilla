# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#dataset load
df = pd.read_csv("Housing.csv")
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
X = df[["area", "bedrooms", "bathrooms", "stories",	"mainroad", "guestroom", "basement", "hotwaterheating",	"airconditioning","parking","prefarea","furnishingstatus"]]
y = df["price"]

# %%
X.isnull().sum()
# Out:
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
#create a plot 
sns.lmplot(data=df,x="area",y="price")

# %%
sns.boxplot(data=df,y="area")
# Out:
# <Axes: ylabel='area'>

# %%
#remove outliers
df = df[(df['area'] > 0) & (df['area'] <10000)]

# %%
sns.boxplot(data=df,y="area")
# Out:
# <Axes: ylabel='area'>

# %%
sns.boxplot(data=df,y="parking")
# Out:
# <Axes: ylabel='parking'>

# %%
sns.boxplot(data=df,y="stories")
# Out:
# <Axes: ylabel='stories'>

# %%
sns.boxplot(data=df,y="bedrooms")
# Out:
# <Axes: ylabel='bedrooms'>

# %%
# #model ko boluy gy
# model = LinearRegression()
# #model ko train kare gy
# model.fit(X, y)
# #model ko predict kare gy
# y_pred = model.predict(X)
# print(y_pred)

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %%
#model ki preprcosseing kary gy
from sklearn.preprocessing import LabelEncoder
#model
le = LabelEncoder()
# encoding the categorical data
le.fit(df["mainroad"])
df["mainroad"]=le.transform(df["mainroad"])
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %%
#model ki preprcosseing kary gy
from sklearn.preprocessing import LabelEncoder
#model
le = LabelEncoder()
# encoding the categorical data
le.fit(df["guestroom"])
df["guestroom"]=le.transform(df["guestroom"])
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %%
cat_col = ["basement","hotwaterheating","airconditioning","parking","prefarea","furnishingstatus"]
le = LabelEncoder()
for col in cat_col:
   df[col] = le.fit_transform(df[col])

df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %%
from sklearn.linear_model import  LinearRegression
model = LinearRegression(
)
#model ko fit karega
model.fit(X, y)
#model ko predict karegy
# y_pred = model.predict(X)
# print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18600\3228156622.py in ?()
#       1 from sklearn.linear_model import  LinearRegression
#       2 model = LinearRegression(
#       3 )
#       4 #model ko fit karega
# ----> 5 model.fit(X, y)
#       6 #model ko predict karegy
#       7 # y_pred = model.predict(X)
#       8 # print(y_pred)
#
# c:\Users\HKT\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
df_1 = df
df_1
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
X_ = df_1[["area", "bedrooms", "bathrooms", "stories",	"mainroad", "guestroom", "basement", "hotwaterheating",	"airconditioning","parking","prefarea","furnishingstatus"]]
y_ = df_1["price"]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#model ko boluy gy
model = LinearRegression()
#model ko train karo gy
model.fit(X_, y_)
#predict model
y_pred = model.predict(X_)
print("Prediction Price:",y_pred)
# Out:
# Prediction Price: [ 8293735.12396092 10689455.78800353  7759807.03487489  8481902.69783122
#   6810909.73093159  8407504.01770331  9804533.0616799   7684261.21735237
#   7698471.83958411  8143467.56976095  7112916.98937729  6092018.56368239
#   6264341.08099066  5088741.52402954  7500789.8668594   8259138.77133151
#   6528612.15337181  6971684.43409749  5372140.82739581  6712706.36103643
#   6177016.38016547  6574589.95598409  7469487.81039785  8197592.02413344
#   8048235.72662223  4768551.58637865  7361477.48820998  7141992.41904743
#   7523920.92462252  6647463.39099029  6854488.40279112  6665399.04496047
#   6475672.60091851  7828872.44147538  7973628.68182565  8506503.68797582
#   6403887.97700367  7152559.47844893  6326219.22491568  7777968.9793008
#   7238510.92581795  6594991.68019644  7373160.73910258  6337954.26914323
#   7269217.93241031  7704434.66972929  4964559.78351713  7147735.06292678
#   7088990.41723741  5960431.9927404   7637030.8056737   7077609.37399917
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#model ko boluy gy
model = LinearRegression()
#model ko train karo gy
model.fit(X_, y_)
#predict model
y_pred = model.predict([[3000,2,3,5,2,1,0,3,4,1,0,1]])
print("Prediction Price:",y_pred)
# Out:
# Prediction Price: [13231005.22375207]
# c:\Users\HKT\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#cross validation
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_, y_, test_size=0.2,random_state=30)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((421, 12), (106, 12), (421,), (106,))

# %%
from sklearn.linear_model import LinearRegression
#model
model = LinearRegression()
#fit
model.fit(X_train, y_train)
#precit
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# [4096487.79609143 3594123.02103583 3728421.37118866 7593192.37972876
#  3820050.19098643 3739649.27212762 2986858.42912691 4764209.74678356
#  7983999.92007548 4373333.68286795 2854819.13805291 3220505.15765729
#  5677023.08181248 3989842.21535418 3279885.16457384 7255436.5523654
#  7919176.94396188 4136644.98718974 6572785.65609652 7114617.10082642
#  4444538.7770828  3444815.04018929 4872371.4882198  7493338.07659805
#  6152323.74387252 3814404.84802185 5784233.91655377 3207902.28073109
#  3144804.1464001  6721757.1871883  5847387.96460398 6201346.67498535
#  5906024.12104446 5637989.79234507 5049477.17272106 3645286.54442524
#  2955028.28733132 5784409.23670068 5622946.89884738 3261890.41162352
#  6107772.3635282  6096864.82903858 6617184.00283969 8238803.27728399
#  7586022.92182583 4137718.18925977 3098844.78259855 5122349.12742408
#  6519909.21132195 4314181.58265409 3496989.8438115  5129581.82845542
#  4660883.74208208 3924847.14931962 5507038.06200292 5178872.82733089
# ...

# %%
from sklearn.linear_model import LinearRegression
#model
model = LinearRegression()
#fit
model.fit(X_train, y_train)
#precit
y_pred = model.predict([[7420,4,2,3,1,0,0,0,1,2,1,0]])
print(y_pred)
# Out:
# [8238803.27728399]
# c:\Users\HKT\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model.score(X_test, y_test)
print("Model Score:", model.score(X_test, y_test))
# Out:
# Model Score: 0.6610540737156558

# %%
# #metrics
# #metrics ky bary ma bat karty ha
# from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
# #data preprocessing
# MSE = mean_squared_error(y_test, y_pred)
# R2 = r2_score(y_test, y_pred)
# MAE = mean_absolute_error(y_test, y_pred)
# print("Mean Squared Error:", MSE)
# print("R-squared:", R2)
# print("Mean Absolute Error:", MAE)

# %%
y_.shape
# Out:
# (527,)
